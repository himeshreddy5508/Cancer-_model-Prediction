# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv('/content/Cancer_data.csv')

# %%
x=df.drop(['Diagnosis'],axis=1)
y=df['Diagnosis']

# %%
from sklearn.model_selection import StratifiedKFold,RandomizedSearchCV

# %%
param_dist = {
    'C': np.logspace(-4, 4, 20),
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear'],   # supports l1 & l2
    'class_weight': [None, 'balanced']
}

# %%
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
cv
# Out:
# StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

# %%
lr2= LogisticRegression(max_iter=1000)

# %%
random_search = RandomizedSearchCV(
    estimator=lr2,
    param_distributions=param_dist,
    n_iter=30,
    scoring='recall',
    cv=cv,
    random_state=42,
    n_jobs=-1,
    verbose=2
)

# %%
random_search.fit(x,y)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=LogisticRegression(max_iter=1000), n_iter=30,
#                    n_jobs=-1,
#                    param_distributions={'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                                         'class_weight': [None, 'balanced'],
#                                         'penalty': ['l1', 'l2'],
#                                         'solver': ['liblinear']},
#                    random_state=42, scoring='recall', verbose=2)

# %%
new_lr2 = LogisticRegression(C=np.float64(0.0006951927961775605), class_weight='balanced',
                   max_iter=1000, penalty='l1', solver='liblinear')

# %%
new_lr2.fit(x_train,y_train)
# Out:
# LogisticRegression(C=np.float64(0.0006951927961775605), class_weight='balanced',
#                    max_iter=1000, penalty='l1', solver='liblinear')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=80,stratify=y)

# %%
x_train,x_test,y_train,y_test
# Out:
# (      Age  Gender        BMI  Smoking  GeneticRisk  PhysicalActivity  \
#  373    30       0  15.080457        0            1          4.652775
#  1373   38       0  32.815533        1            2          6.900754
#  88     61       0  24.982898        1            0          4.104987
#  181    45       0  30.380486        0            0          3.902385
#  1072   74       0  34.723312        0            0          9.074632
#  ...   ...     ...        ...      ...          ...               ...
#  876    64       0  22.231119        1            0          6.155526
#  654    35       0  25.563711        0            1          3.789559
#  394    60       1  34.622424        0            1          7.228392
#  59     23       0  35.008913        0            0          0.819384
#  1209   63       0  37.253528        0            0          0.438811
#
#        AlcoholIntake  CancerHistory
#  373        3.560360              0
#  1373       0.191014              0
# ...

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
lr2=LogisticRegression()
lr2.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr2= LogisticRegression(max_iter=1000)
lr2.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score
y_pred=new_lr2.predict(x_test)

# %%
y_pred=new_lr2.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6283333333333333

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(lr2, x_train, y_train, cv=11)

# %%
print(scores.max())
print(scores.mean())
print(scores.min())
# Out:
# 0.9135802469135802
# 0.8533574224631135
# 0.7804878048780488

# %%
from sklearn.metrics import recall_score
recall_score(y_test,y_pred)
# Out:
# 0.0
